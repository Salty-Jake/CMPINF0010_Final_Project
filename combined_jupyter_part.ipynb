# %% [markdown]
# Housing Inspection

# %% [markdown]
# This data shows the housing inspections and violations. The rate of violations to inspections varied from neighborhood to neighborhood

# %% [markdown]
# 2010 Snap Transportation Data

# %% [markdown]
# This data shows the percentage of people in each neighborhood who use public transportation to commute to work. The percantage varied greatly between neighborhoods

# %% [markdown]
# Grocery Stores Inspections

# %% [markdown]
# This data measures the inspections and violations stores have in unfair prices. A lot of neighborhoods had little to no violations, making them have a low rate.

# %% [markdown]
# Conclusion:
# The store inspection and transportation had detailed data about the districts within the city of Pittsburgh. The housing data had Pittsburgh as just a general combined category within the city, and more detailed data for many of the suburbs around Pittsburgh. These differences in data make it difficult to combine them all, since only a few neighborhoods are shared among all three data sets. For weighing the data, we used a "less is more" approach for the Housing and Store violation rate. For transportation data, we considered neighborhoods with a lower percentage of people using public transportation as better (because using public transportation usually means one is too poor for a car).

# %% [markdown]
# Winner: <br>
# The winning neighborhood was East Carnegie!!! <br>
# Housing Inspection Violation Ratio: 5.19 <br>
# Public Transportation rate: 0.00% <br>
# Grocery Store Violation Rate: 1.17% <br>
# It scored as one of the best for Transportation and Stores, while being average in housing. Overall, the data shows that East Carnegie is the best neighborhood to live in within Pittsburgh.
